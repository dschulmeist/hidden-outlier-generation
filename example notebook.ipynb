# %%
from pyod.models.lof import LOF 
from multibisect.Bisect import BisectHOGen
import tensorflow as tf

#get mnist data
X_train = tf.keras.datasets.mnist.load_data()[0][0]
X_train = X_train.reshape(-1, 28*28)[:1000]

# %%
bisect = BisectHOGen(data=X_train, outlier_detection_method=LOF)
fake_points = bisect.main_multi_bisect(gen_points=100, n_jobs=-1)
# Out:
# 2023-09-07 20:51:55,072 - INFO - Fitting all subspaces....
# 2023-09-07 20:52:04,646 - INFO - Fitting in the full space....
# 2023-09-07 20:52:04,731 - INFO - Set of fitted Subspaces size: 1569
# given Origin method: weighted
# Calculating probability vector...
# Done!
# Generating 100 hidden outlier points...
# n jobs:  -1
# 2023-09-07 20:52:11,443 - INFO - Processing point 0
# 2023-09-07 20:52:11,493 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,539 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,560 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,562 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,603 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,605 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,607 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,621 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,624 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,626 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,670 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,672 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,675 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,683 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,688 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,692 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,691 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,695 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,699 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,789 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,791 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,794 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,796 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,798 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,801 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,804 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,811 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,814 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,823 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,836 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,847 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,869 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,877 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,897 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,900 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,903 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,920 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,923 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,924 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,926 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,946 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,949 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,951 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,954 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,957 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,960 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,965 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,968 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,978 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,978 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,984 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,985 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,987 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,988 - INFO - x Outside of bounds
# 2023-09-07 20:52:11,990 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,003 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,026 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,029 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,032 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,033 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,036 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,040 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,043 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,048 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,054 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,066 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,069 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,073 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,077 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,084 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,084 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,087 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,092 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,097 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,102 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,102 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,104 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,108 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,109 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,126 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,129 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,134 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,137 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,139 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,146 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,148 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,151 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,152 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,155 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,179 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,182 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,186 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,188 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,191 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,202 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,205 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,208 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,211 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,213 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,216 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,219 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,221 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,222 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,224 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,249 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,277 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,279 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,288 - INFO - x Outside of bounds
# 2023-09-07 20:52:12,290 - INFO - x Outside of bounds
# Done! Exec time:  17.430810928344727

# %%
fake_points.shape
# Out:
# (100, 784)

# %%
import matplotlib.pyplot as plt

nrows = 10
ncols = 10

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10, 10))
for i in range(nrows):
    for j in range(ncols):
        axes[i, j].imshow(fake_points[i*ncols+j].reshape(28, 28), cmap='gray')
        axes[i, j].axis('off')  
plt.show()

# %%
bisect.print_summary()
# Out:
# Hidden Outlier Generation Method Object
#
# Outlier detection method used: LOF
# Synthetic HO generation method employed: multi_bisection.
#
# Database summary:
#
# * Number of features: 784
# * Total number of data points: 1000
# * Total amount of synthetic data generated: 100
# 	...of which hidden outliers: 100
# * Number of H1 outliers: 100
# * Number of H2 outliers: 0.
#
# Total execution time: 17.430810928344727.
